# %% [markdown]
# # Logistic Regression
# Tennis Data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pp
# %matplotlib inline

# %%
#read in the data
td = pd.read_csv('Tennis data.csv')
td.head(5)
# Out:
#               Player1          Player2  Result  FSP  FSW  SSP  SSW  ACE  DBF  \
# 0     Richard Gasquet  Michael Russell       1   63   55   64   16    7    7
# 1     Stephane Robert  Albano Olivetti       1   61   56   77   19    3    2
# 2  Jan-Lennard Struff  Guillaume Rufin       0   55   39   47   32   11   13
# 3        Aljaz Bedene  Dmitry Tursunov       0   52   59   39   19   13    8
# 4     Feliciano Lopez    Florent Serra       1   58   46   50   30   21    3
#
#    NPA  NPW
# 0    6   59
# 1    6   56
# 2    3   55
# 3    6   55
# 4    6   61

# %%
td.describe()
# Out:
#            Result         FSP         FSW         SSP         SSW         ACE  \
# count  126.000000  126.000000  126.000000  126.000000  126.000000  126.000000
# mean     0.468254   58.650794   52.563492   57.880952   23.380952    8.507937
# std      0.500983    7.134499   14.223078   13.331831    8.700213    5.333286
# min      0.000000   38.000000   13.000000   24.000000    8.000000    0.000000
# 25%      0.000000   53.000000   43.000000   49.000000   17.000000    5.000000
# 50%      0.000000   59.000000   53.000000   57.500000   23.000000    8.000000
# 75%      1.000000   63.000000   62.000000   69.000000   29.000000   11.000000
# max      1.000000   75.000000   86.000000   92.000000   45.000000   29.000000
#
#               DBF         NPA         NPW
# count  126.000000  126.000000  126.000000
# mean     4.952381    4.888889   58.920635
# std      2.998285    1.693386    7.432473
# min      0.000000    1.000000   44.000000
# 25%      3.000000    3.000000   55.000000
# ...
